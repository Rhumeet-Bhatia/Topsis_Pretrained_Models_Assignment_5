# %%
# !python ../src/topsis_text_generation.py
# Out:
#             Model  TOPSIS Score
# 1      distilgpt2      0.836426
# 3     pythia_160m      0.492667
# 4  dialogpt_small      0.478897
# 2    gpt_neo_125M      0.470496
# 0            gpt2      0.299504
# Figure(640x480)
